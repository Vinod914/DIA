# %%
import requests
from bs4 import BeautifulSoup
from io import BytesIO
from PIL import Image
import pytesseract
import pandas as pd
import re
def extract_image_links(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    img_tags = soup.find_all("img")
    img_links = []
    for img in img_tags:
        img_link = img.get("src")
        if img_link.endswith(".jpg") or img_link.endswith(".jpeg") or img_link.endswith(".png"):
            img_links.append(img_link)
    return img_links,soup
# Function to fetch text from image using Tesseract OCR
def extract_text_from_image(image):
    try:
        image = Image.open(BytesIO(image))
        text = pytesseract.image_to_string(image)
        return text.strip()  # Remove leading/trailing white spaces from the extracted text
    except TesseractNotFoundError:
        print("Tesseract is not installed or not found in the system's PATH.")
        return None
    except Exception as e:
        print(f"Error in image processing: {e}")
        return None

# Function to fetch text from a webpage and images in the page
def fetch_text_from_url(url):
    # Fetch webpage content
    
    img_links,soup = extract_image_links(url)

    # Extract text from webpage content
    text_content = soup.get_text()

    # Extract alt text from images in the page
    image_alt_text = []
    for img in soup.find_all('img'):
        if 'alt' in img.attrs:
            image_alt_text.append(img.attrs['alt'])

        # Extract text from images in the page
        '''if 'src' in img.attrs:
            image_src = img.attrs['src']
            if image_src.endswith('.png') or image_src.endswith('.jpg'):
                image_response = requests.get(image_src)
                image_text = extract_text_from_image(image_response.content)
                image_alt_text.append(image_text)'''

    # Combine webpage text and image alt text
    text_content += ' '.join(image_alt_text)

    return text_content

# Function to remove non-alphabetic characters from text
def remove_non_alpha(text):
    return re.sub(r'[^a-zA-Z\s]', '', text)

# Function to determine if text is gender biased
def is_gender_biased(text):
    # Read Excel file containing gender-biased words
    df = pd.read_excel('gender_biased_words.xlsx', sheet_name='word')
    biased_words = df['word'].tolist()

    # Check if any biased word is present in the text
    text_words = set(text.lower().split())
    biased_words_set = set([word.lower() for word in biased_words])
    if len(text_words.intersection(biased_words_set)) > 0:
        return True

    return False

# Example usage
url = 'https://avinuty.ac.in/'
text_content = fetch_text_from_url(url)
text_content = remove_non_alpha(text_content)  # Remove non-alphabetic characters
if is_gender_biased(text_content):
    print('The text is gender biased')
else:
    print('The text is not gender biased')
# Out:
# The text is gender biased

# %%
url='https://www.accenture.com/in-en'
l=fetch_text_from_url_teamp(url)

# %%
import requests
from bs4 import BeautifulSoup
from io import BytesIO
from PIL import Image
import pytesseract
import pandas as pd
import re


def extract_image_links(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    img_tags = soup.find_all("img")
    img_links = []
    for img in img_tags:
        img_link = img.get("src")
        if img_link.endswith(".jpg") or img_link.endswith(".jpeg") or img_link.endswith(".png"):
            img_links.append(img_link)
    return img_links, soup


def extract_text_from_image(image):
    try:
        image = Image.open(BytesIO(image))
        text = pytesseract.image_to_string(image)
        return text.strip()  # Remove leading/trailing white spaces from the extracted text
    except pytesseract.TesseractNotFoundError:
        print("Tesseract is not installed or not found in the system's PATH.")
        return None
    except Exception as e:
        print(f"Error in image processing: {e}")
        return None


def fetch_text_from_url(url):
    img_links, soup = extract_image_links(url)
    text_content = soup.get_text()
    image_alt_text = []
    for img in soup.find_all('img'):
        if 'alt' in img.attrs:
            image_alt_text.append(img.attrs['alt'])
    text_content += ' '.join(image_alt_text)
    return text_content


def remove_non_alpha(text):
    return re.sub(r'[^a-zA-Z\s]', '', text)


def find_biased_sentences(text, biased_words):
    sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s', text)
    biased_sentences = []
    for sentence in sentences:
        if any(word.lower() in sentence.lower().split() for word in biased_words):
            biased_sentences.append(sentence)
    return biased_sentences


url = 'https://avinuty.ac.in/'
text_content = fetch_text_from_url(url)
text_content = remove_non_alpha(text_content)

df = pd.read_excel('gender_biased_words.xlsx', sheet_name='word')
biased_words = df['word'].tolist()

biased_sentences = find_biased_sentences(text_content, biased_words)
if biased_sentences:
    print("Biased sentences:")
    for sentence in biased_sentences:
        print(sentence)
else:
    print("No biased sentences found.")
# Out:
# Biased sentences:
#
#
#
#
#
#
#
#
# Avinashilingam University for Women  Coimbatore  Tamil Nadu  India
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   Avinashilingam Institute for Home Science and Higher Education for Women
#
#
#   Deemed to be University  Estd us  of UGC Act  Category A by MHRD
#   Reaccredited with A Grade by NAACCGPA  Category I by UGC
# Coimbatore  Tamil Nadu India
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Accessibility Options
# Screen reader
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Menu
#
#
#
#
#
#
#
# About Us
#
# Founder
# Genesis
# About us
# Vision and Mission
# Vision
#
# Chair
#
#  Padmabhushan DrTSAvinashilingam Ayya
#
#  DrPRajammmal PDevadas
#  Swami Jagadatmananda Saraswati
#  TSDhadapani Chettiar
#
#
#
# Core Values
#
#
# Strategic Plan
#
#
#  Perspective  Deployment Plan
#
#
# Organogram
# Know our InstitutionVideo
# Institutional Distinctiveness
# Best Practices
#
#
#
#
#
# Authorities
#
# Chancellor
#
# Vice Chancellor
# Deans of Schools
#
# Statutory Body  other committees
#
# General body
#  Board of Management
#
#  Planning  Monitoring
#  Academic Council
#
# Boards of Studies
#
#  Finance Committee
# Building Committee
# Library Committee
# Other Committees
#
#
#
#
#
#
#
# Administration
#
# Registrar
# Registrars Office
#
#  Academic Section
#  Administration Section
#
# Controller of Examinations
# Public Relation Office
#  Finance Office
#  PoliciesManuals
#  Reservation Roster
# LiaisonNodal Officer
# Citizen Charter
# Staff Directory
#
#  Teaching
#  NonTeaching
#
#
#
#
#
#
#
# Academics
#
#  Programmes offered
#
#
#
#  Programme Outcomes
#  Hand Book  Calendar
#
# Curriculum Framework
#
#   Outreach Programmes
#
#
#
#
#
#
#
# Research
#
#  Research
#
#
# Centralized Facilities
#
#  Advanced Research Lab
#
#  Prof CNR Rao Research Centre
# Center for Machine Learning and Intelligence
#  Centre for Artificial Intelligence and Robotics
#  CMET Research Centre
# Innovation and Incubation Cente
# AIUAIAADC
# Entrepreneurship Development Cell
# Institutions Innovation Council
#
#
#  Facilities to Support Research
#
#
#
#
#
# Examination
#
#
# Manual and Evaluation
# IT Integration
#
# Calendar of Events
#
#
# 								        Odd Semester Calendar of Events for all programmes except First Year
#
# 								       Odd Semester Calendar of Events for all first year programmes
#
# 								        Revised Even Semester Calendar of Events for all programmes
#
#
#
#
# Results
#
# Time table
# Revaluation Retotalling  Transparency
#
#
# Certificates
#
# Duplicate Certificate
# Transcript Certificate
# Genuniness Certificate
#
#
#  Comprehensive Question Paper Templates
#  Evaluation  Assessment Rubrics
# PhD Tracking System
# UGCNAD Digilocker
#
#
#
#
#
#
# Schools
#
#  School of Home Science
#  School of Physical Sciences  Computational Sciences
#  School of Biosciences
#  School of Arts  Social Sciences
# School of  Commerce  Management
# School of Allied and Healthcare Sciences
#  School of Education
#
#  School of Engineering
#
#
#
#
#
# Facilities
#
# Library
#
# Computer Centre
#
#
#
# eresources
#
# Library eresources
# Internal platform
#
# ecampus LMS
# Google Class room
#
#
#  External platform
#
# SWAYAM MOOC
# epgPathsala
# NMEICT
#
#
#
#
#
#
#
# Centres
#
#  Academic  Service Centres
#
# Centre for International Education
# Womens Studies Centre
#
#  Gandhian Studies Centre
#   DrAmbedkar Studies Centre
# Life Long Learing Centre
#
#
#  Centralized Facilities
#
#  Advanced Research Lab
#
#  Prof CNR Rao Research Centre
# Center for Machine Learning and Intelligence
#  Centre for Artificial Intelligence and Robotics
#  CMET Research Centre
# Innovation and Incubation Cente
# AIUAIAADC
# Entrepreneurship Development Cell
# Institutions Innovation Council
#
#
#
# Skill Training Centre
#
#
#
#
#
# Infrastructure
#
#
#  Teaching  Learning
# Laboratory
# Other Facilities
# Divyangjan Facilities
#
# Facilities for Differently Abled
#
# Divyangjan Friendliness Resources
#
#  Ramp Rail and Lift Facility
#  Disabled Friendly Washroom
#  Signage
#  Assistive Technology and Facilities
#
#
#
#
# Hostel
# CARE
#
# Media Centre
#
# Other Facilities
#
# Hostel
# Auditorium
# Canteen
# Health Centre
# Saradalaya Press
#
#
#
#  IMF
#
# Green Initiatives
#
#
# Energy Conservation
#
# Solar Energy
# Biogas Plant
# Sensor Based energy conservation
# Use of LED Lights
#
#
#
# Management of Waste
#
# Solid Waste Management
# Liquid Waste Management
# Biomedical Waste Management
# E waste Management
# Waste Recycling System
#
#
#
# Water Conservation Measures
#
# Rain Water Harvesting
# Borewell Open well Recharge
# Construction of Tanks  Bunds
# Waste Water Recycling
#
#
#
# Green Campus Initiatives
#
# Restricted entry of automobiles
# Use of BicyclesBattery powered vehicle
# Pedestrian Friendly pathways
# Ban on use of Plastic
# Landscaping with trees and plants
#
#
#
#
#
# ICT Facilities
#
#
# ICT Video
# ICT Facilities  short video
#
#
# Sports
# Facilities for Staff
#
#
#
#
#
#  Admissions
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Admission  Online Applications open for UG PG BEdBPEdMEd Diploma  PhD courses
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Announcements
#
#
#
#
#
#  View all
#
#
#
#
#
#
#
#
#             Sealed tenders are invited for the  design and development of our institution website Last date to apply
#
#
#             Sealed tenders are invited for  Civil Maintenance Work in School of Engineering Campus Last date to apply
#
#
#            Circular for Vacation details
#
# Parents Meeting of the  newly admitted for UG courses
#
# Campus I
#
# Campus II
#
#
#              CIA II Time Table for PhD Degree Programme Part I  Part Time  Batch  May
#
#
#
#  CIA  II Time Table for All Programmes UG PG BVoc  PG Diploma  April
#
#
#
#
#
#
#  Comprehensive Examination   May  Regular  Arrear  Examination Time Table for all Programmes
#
#
#
#
#
#              Remittance of Even Semester Fee for Academic year
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Quick Links
#
# Staff Corner
#
#    Student Corner
#   Recruitments
#   External links
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    Academic Bank of Credits
#
#
# 	   National Academic Depository
#
#     	 UGC eresources
#
#     	   ePgpathsala
#   Spoken Tutorial
# DSource
#
# eyantra
#
# Vidyamitra
#
#
#
#
#  Swayam MOOC Courses offered
#
#
#
#
#
#
#
#
#
#
#
#
# CircularsGuidelines
#
#
#
#
#
#
#
#
#
# Announcements
#
#
#
#    Scholarship
#
#
#
#     Facilitation Centre  Scholarship Help Desk SCST
#
#
#
# Rules  Regulations
#
#
#    Swayam MOOC Courses offered
#
#
#
#
#
#     Recruitment
#
#
#
#
#
#
#
#
#
#
#
#
#    RTI Act
#
#
#
#      Anti Ragging Cell
#
#
#
#     Equal Opportunity Cell
#
#
#    SCST  OBC Complaints
#
#
#
#
#      Grievance Redressal Cell
#
#
#
#
#
#  Internal Complaints Committee SH
#
#
#
#       Student Capability Enhancement
#
#      Student Council
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                             Self development and empowerment of women through modern scientific and value based education to enable them to lead
#                         a purposeful life filled with moral and spiritual values
#
# The Mission of the  University is to provide quality education of global standards on a strong foundation of Indian values and traditions to women students
# based on current advances in science technology and societal demands with emphasis on commitment to social progress peace harmony and national integration
#
#
#
#
#
#
#
#
#  Academic  Excellence
# Our Institution strives to meet  the highest standard of excellence in virtual and ICT enabled teaching learning methodology research continuous  inhouse and outbound Faculty  Improvement Programmes    ensures continuous engagement in the scholarly activities in the pursuit of leveraging  innovation creativity and excellence Brings up to date  changes  in academic activity to  implement systems and navigate   the  functions to inorder to meet the sustainable education standards and practices Our research activities and outcomes   continue to have global significance  and meaningful impact
#
# Social Relevance and Women empowerment
#
# 							Promotes National Integration among the students  through implementing the policies by means of NCC NSS CSS Yoga Sports and  encourage students to be participative in all intra and inter competitions and social awareness programmes Imparts skill based education and learning in empowering women to venture into start up businesses encourage women to hold leadership roles and facilitate   in sourcing   their dream  career by extending relevant training and industry awareness programmes
#
#  Accountability and Transparency
#
# 							Issues in internal governance of the institution in terms of the processes connected with admissions registration examinations evaluations payment of fees and a host of other functions are addressed with   close attention in ensuring quality and transparency  It  promotes continuous improvement and take responsibility for professional growth and development of the students staff and institute by egovernance and  digitalization where its use make  all the stake holders of the institute to work at ease
#
# Diversity  Inclusion
#
# Upholds the highest ethical values integrity and   professionalism by fostering   inclusive environment  where everyone can develop their full potential and contribute to the interest of the society as a whole and perform well in their careers Ensures non discrimination and promotes inclusion in all levels of education
#
# Vitality of Culture and Values
#
# Our Institution embraces cultural values across the institution and treat people with dignity  and encourage feelings of importance in all All festivals  and its values are celebrated with all its pomp and glory Traditional values and prayers are followed  Gandhian  principles and Dr Ambedkars thoughts are shared and adopted
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Upcoming Events
# 							 View all
#
#
#
#
#
#
#
#
# Five days Summer Camp  YOU TOO CAN SING from  to
#
#
#
# days Summer Camp  Spoken Hindi course  to
#
#
#
#
#  International Conference on Innovative Applications of Artificial Intelligence IAAI   th  th Sep
#
#
#
#    PhD Vivavoce Exam Notification
#
#
#
#
#
#
#
#
#
#  Photo galleryEvents
#                         	  View all
#
#
#
#
#
#
#     Pudhumai Penn scheme  Appreciation ceremony
#
#
#
#      Lighting  Ceremony in honour of outgoing students
#
#
#
#
#      NATCON
#
#
#
#
#      TECHWINGS K
#
#
#
#
#      AVEGA
#
#
#
#      Int Conference on Revamping Food and Nutrition for the Next Generation  Addressing Personal Public and Planetary Sustainable Health Mar
#
#
#
#
#
#
#
#
#
#
# th Convocation
#
#
# Campus Tour
#
# Campus Tour
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Links
#
#
#   Vidwan
#   Shodhganga
#    National Cyber Crime Reporting Portal
#    National Council for Teacher Education
#    IQAC
#    NAAC
#    NIRF
#
#
#
#
#
# Digital Action Plan
#
#   Academic Bank of Credits
#   National Academic Depository
#  UGC eresources
#   ePgpathshala
#   Swayam
#   Swayam Prabha
#   UGCMOOCS
#
#
#
#
#
# Keep in Touch
#
#
#
#
#
#
#
#
#
#  Mandatory Diclosure
#
#
#
#
#
#
#
#
#
#
#
#
# Visitors Count
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Logo new new   new new new new new new new new new           new   new new new new

# %%
import requests
from bs4 import BeautifulSoup
from io import BytesIO
from PIL import Image
import pytesseract
import pandas as pd
import re
import sys


def extract_image_links(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    img_tags = soup.find_all("img")
    img_links = []
    for img in img_tags:
        img_link = img.get("src")
        if img_link.endswith(".jpg") or img_link.endswith(".jpeg") or img_link.endswith(".png"):
            img_links.append(img_link)
    return img_links, soup


def extract_text_from_image(image):
    try:
        image = Image.open(BytesIO(image))
        text = pytesseract.image_to_string(image)
        return text.strip()  # Remove leading/trailing white spaces from the extracted text
    except pytesseract.TesseractNotFoundError:
        print("Tesseract is not installed or not found in the system's PATH.")
        return None
    except Exception as e:
        print(f"Error in image processing: {e}")
        return None


def fetch_text_from_url(url):
    img_links, soup = extract_image_links(url)
    text_content = soup.get_text()
    image_alt_text = []
    for img in soup.find_all('img'):
        if 'alt' in img.attrs:
            image_alt_text.append(img.attrs['alt'])
    text_content += ' '.join(image_alt_text)
    return text_content


def remove_non_alpha(text):
    return re.sub(r'[^a-zA-Z\s]', '', text)


def find_biased_sentences(text, biased_words):
    sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s', text)
    biased_sentences = []
    for sentence in sentences:
        for word in biased_words:
            if word.lower() in sentence.lower().split():
                biased_sentences.append((word, sentence))
                break
    return biased_sentences


def print_biased_sentences(biased_sentences):
    if biased_sentences:
        print("Biased sentences:")
        for word, sentence in biased_sentences:
            highlighted_sentence = highlight_word_in_sentence(word, sentence)
            print(f"\033[91mBiased word: {word}\033[0m")
            print(highlighted_sentence)
            print()
    else:
        print("No biased sentences found.")


def highlight_word_in_sentence(word, sentence):
    highlighted_sentence = sentence.lower().replace(word.lower(), f"\033[91m{word.upper()}\033[0m")
    return highlighted_sentence


url = 'https://www.accenture.com/'
text_content = fetch_text_from_url(url)
text_content = remove_non_alpha(text_content)

df = pd.read_excel('gender_biased_words.xlsx', sheet_name='word')
biased_words = df['word'].tolist()

biased_sentences = find_biased_sentences(text_content, biased_words)
print_biased_sentences(biased_sentences)
# Out:
# Biased sentences:
# Biased word: man
#
#
#
#
#
# accenture  india  let there be change
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# skip to main content
# skip to footer
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# insights
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			featured content
#
#
#
# voices of change
#
# the path to  value starts herefeaturing our most provocative thinking extensive research and compelling stories of shared success
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# g
#
#
#
#
# artificial intelligence
#
#
#
#
# blockchain
#
#
#
#
# cloud
#
#
#
#
# customer experience
#
#
#
#
# cybersecurity
#
#
#
#
# digital engineering  MANufacturing
#
#
#
#
# digital transformation
#
#
#
#
# edge computing
#
#
#
#
# future of work
#
#
#
#
# metaverse
#
#
#
#
# supply chain
#
#
#
#
# sustainability
#
#
#
#
# podcasts
#
#
#
#
# blogs
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# services
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# application services
#
#
#
#
# artificial intelligence
#
#
#
#
# automation
#
#
#
#
# business process outsourcing
#
#
#
#
# business strategy
#
#
#
#
# change MANagement
#
#
#
#
# cloud
#
#
#
#
# customer experience
#
#
#
#
# data  analytics
#
#
#
#
# digital commerce
#
#
#
#
# digital engineering  MANufacturing
#
#
#
#
# ecosystem services
#
#
#
#
# finance consulting
#
#
#
#
# infrastructure
#
#
#
#
# marketing
#
#
#
#
# mergers  acquisitions ma
#
#
#
#
# metaverse
#
#
#
#
# operating models
#
#
#
#
# security
#
#
#
#
# supply chain MANagement
#
#
#
#
# sustainability
#
#
#
#
# technology consulting
#
#
#
#
# technology innovation
#
#
#
#
# zerobased transformation
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# industries
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aerospace and defense
#
#
#
#
# automotive
#
#
#
#
#  banking
#
#
#
#
#  capital markets
#
#
#
#
# chemicals
#
#
#
#
#  communications and media
#
#
#
#
#  consumer goods and services
#
#
#
#
#  energy
#
#
#
#
# health
#
#
#
#
#  high tech
#
#
#
#
#  industrial
#
#
#
#
#  insurance
#
#
#
#
# life sciences
#
#
#
#
# natural resources
#
#
#
#
#  public service
#
#
#
#
#  retail
#
#
#
#
# software and platforms
#
#
#
#
#  travel
#
#
#
#
# utilities
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# careers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# careers home
#
#
#
#
# search jobs
#
#
#
#
#
#
#
#
#
#
# join us
# join us
#
# careers
#
#
# search and apply
#
#
#
#
# experienced professionals
#
#
#
#
# training  development
#
#
#
#
# work environment
#
#
#
#
#
#
#
#
#
#
# explore jobs
# explore jobs
#
# careers
#
#
# search jobs by areas of expertise
#
#
#
#
# consulting jobs
#
#
#
#
# corporate jobs
#
#
#
#
# digital jobs
#
#
#
#
# operations jobs
#
#
#
#
# strategy jobs
#
#
#
#
# technology jobs
#
#
#
#
# industry x
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# about accenture
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# who we are
# who we are
#
# about accenture
#
#
# about accenture
#
#
#
#
# leadership
#
#
#
#
# how we work with clients
#
#
#
#
# case studies
#
#
#
#
# newsroom
#
#
#
#
# investor relations
#
#
#
#
# inclusion  diversity
#
#
#
#
# sustainability
#
#
#
#
#
#
#
#
#
#
# how were organized
# how were organized
#
# about accenture
#
#
# strategy  consulting
#
#
#
#
# song
#
#
#
#
# technology
#
#
#
#
# operations
#
#
#
#
# industry x
#
#
#
#
#
#
#
#
#
#
# in india
# in india
#
# about accenture
#
#
# about accenture in india
#
#
#
#
# inclusion  diversity in india
#
#
#
#
# accelerating equality with vaahini
#
#
#
#
# corporate citizenship in india
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# contact us
#
#
#
#
#
#
# your browser does not support javascript some
# 	components may not be visible
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# your browser does not support javascript some
# 	components may not be visible
#
#
#
#
#
#
# current country united states
#
#
#
#
#
# default english
# all countries  languages
#
# argentina spanish
#
#
# australia english
#
#
# austria gerMAN
#
#
# belgium english
#
#
# brazil portuguese
#
#
# bulgaria english
#
#
# canada french
#
#
# canada english
#
#
# chile spanish
#
#
# chinahong kong sar english
#
#
# chinamainland chinese
#
#
# chinamainland english
#
#
# colombia spanish
#
#
# costa rica english
#
#
# czech republic english
#
#
# denmark english
#
#
# finland english
#
#
# france french
#
#
# gerMANy gerMAN
#
#
# greece english
#
#
# hungary english
#
#
# india english
#
#
# indonesia english
#
#
# ireland english
#
#
# israel english
#
#
# italy italian
#
#
# japan japanese
#
#
# latvia english
#
#
# luxembourg english
#
#
# malaysia english
#
#
# mauritius english
#
#
# mexico spanish
#
#
# morocco english
#
#
# netherlands english
#
#
# new zealand english
#
#
# norway english
#
#
# philippines english
#
#
# poland polish
#
#
# portugal portuguese
#
#
# roMANia english
#
#
# saudi arabia english
#
#
# singapore english
#
#
# slovakia english
#
#
# south africa english
#
#
# spain spanish
#
#
# sweden english
#
#
# switzerland english
#
#
# thailand english
#
#
# uae english
#
#
# united kingdom english
#
#
# usa english
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# case studies  stories
#
#
#
#
#
# join our team
#
#
#
#
#
# ideas that make an impact
#
#
#
#
#
# leading through change
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# reinvent what your business could be
#
#
#
#
# discover how leaders can harness the five key forces of change
#
#
#
#
# read more
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# reinventing enterprise operations
#
#
#
#
# how optimizing operations can help to access a new perforMANce frontier
#
#
#
#
#
# read our new report
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# a new era of generative ai for everyone
#
#
#
#
# the technology underpinning chatgpt will transform work and reinvent the business
#
#
#
#
# read more
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# total enterprise reinvention
#
#
#
#
# the strategy that leads to a new perforMANce frontier
#
#
#
#
# read our new report
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# previous
#
#
#
# next
#
#
#
# pause
#
#
#
# play
#
#
#
# slide
# slide
# slide
# slide
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# case studies  stories
#
#
#
#
# see how we create  value and help clients become the next and best versions of themselves
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# changi airport
# enter the changiverse
# changi airport group teams up with accenture to launch digital wonderland changiverse
#
#
#
# explore
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# australian institute of marine science
# a second chance for coral
# reefcloud diving into deep learning to protect coral reefs
#
#
#
# explore
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# axa belgium
# axas claims in the cloud
# building cuttingedge aws insurance capabilities
#
#
#
# explore
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# petrofac
# petrofac digital transformation through connected workers
# accenture worked with petrofac to develop one of the energy industrys first connected worker solutions
#
#
#
# explore
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# netflix
# vfx brings imagination to life
# stunning netflix visual effects
#
#
#
# explore
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# duke energy
# duke energy powers platform for methane reduction
# firstofitskind endtoend methane emissions monitoring and remediation solution
#
#
#
# explore
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# shiseido
# change thats more than skin deep
# how shiseido is using digital to create new beauty experiences
#
#
#
# explore
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bt group
# a global hr transformation
# bt group puts people at the center of change
#
#
#
# explore
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# egeos
# unlocking the secrets of space data
# how egeos is bringing satellite observation to everyone
#
#
#
# explore
#
#
#
#
#
# card
# card
# card
# card
# card
# card
# card
# card
# card
#
#
#
#
#
# explore
#
#
#
#
#
# previous
#
#
#
#
#
# next
#
#
#
#
#
# see all stories
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# join us
#
#
#
#
# unlock your potential in every direction
#
#
#
# search and apply
#
#
#
# scroll
#
#
#
#
#
#
#
#
#
#
#
#
#
# reimagine your career
#
# your career is about what you want to be and who you want to be its about bringing your skills your curiosity and  your best true self to your work
# here youll match your ingenuity with the latest technology to make incredible things
# together lets create positive longlasting value
#
#
#
#
# search and apply
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# insights to help you stay ahead of change
#
#
#
#
# from insights to action the path to  value starts here
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# explore
#
#
#
# technology
#
# technology vision
#
# when atoms meet bits the foundations of our new reality
#
#
#
#
# explore
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# explore
#
#
#
# cloud data  ai
#
# cloud data a new dawn for dorMANt data
#
# explore six foundational data practices to create measurable business value
#
#
#
#
# explore
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# explore
#
#
#
# metaverse
#
# metaverse evolution then revolution
#
# gradually then suddenly the metaverse is changing the way we experience the internet
#
#
#
#
# explore
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# explore
#
#
#
# sustainability
#
# ungcaccenture ceo study on sustainability
#
# the latest ceo study on sustainability provides perspectives and a resolute call from a record  ceos across  countries and  industries
#
#
#
#
# explore
#
#
#
# explore
#
#
#
#
# explore latest insights
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# let there be change
#
#
#
#
#
#
#
#
# our goal is to create  value for all our stakeholdersour clients people shareholders partners and communities this goal reflects our growth strategy our purpose our core values and our culture of shared success
#
#
#
#
#
#
# julie sweet
#
#
#
#
# chair  ceo
#
#
#
#
#  twitter
#
#
#
#  linkedin
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# visit our subscription and preference center
#
#
#
# subscribe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	        			about us
#
#
#
#
# 	        			contact us
#
#
#
#
# 	        			careers
#
#
#
#
# 	        			locations
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	        			privacy statement
#
#
#
#
# 	        			terms  conditions
#
#
#
#
# 	        			cookie policy
#
#
#
#
# 	        			accessibility statement
#
#
#
#
# 	        			sitemap
#
#
#
#
# 				      accenture all rights reserved
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# accenture india changi in roblox corals under the sea woMAN looking to monitor MAN working MAN in fire dam and the forest woMAN in white dress discuss something in desktop space satellite  accenture a freeway across the seaside conductors hand holding a baton two women in purple holding hands a split comparison of a dry barren land to mountain and a greener healthy forest mountain    accenture home

# %%
import requests
from bs4 import BeautifulSoup
from io import BytesIO
from PIL import Image
import pytesseract
import pandas as pd
import re


def extract_image_links(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    img_tags = soup.find_all("img")
    img_links = []
    for img in img_tags:
        img_link = img.get("src")
        if img_link.endswith(".jpg") or img_link.endswith(".jpeg") or img_link.endswith(".png"):
            img_links.append(img_link)
    return img_links, soup


def extract_text_from_image(image):
    try:
        image = Image.open(BytesIO(image))
        text = pytesseract.image_to_string(image)
        return text.strip()  # Remove leading/trailing white spaces from the extracted text
    except pytesseract.TesseractNotFoundError:
        print("Tesseract is not installed or not found in the system's PATH.")
        return None
    except Exception as e:
        print(f"Error in image processing: {e}")
        return None


def fetch_text_from_url(url):
    img_links, soup = extract_image_links(url)
    text_content = soup.get_text()
    image_alt_text = []
    for img in soup.find_all('img'):
        if 'alt' in img.attrs:
            image_alt_text.append(img.attrs['alt'])
    text_content += ' '.join(image_alt_text)
    return text_content


def remove_non_alpha(text):
    return re.sub(r'[^a-zA-Z\s]', '', text)


def is_word_present(sentence, word):
    # Split the sentence into individual words
    words = sentence.split()

    # Iterate over the words and check for a match
    for w in words:
        # Remove any punctuation marks from the word
        clean_word = ''.join(c for c in w if c.isalnum())

        # Compare the clean word with the target word
        if clean_word.lower() == word.lower():
            return True

    # No match found
    return False


def find_biased_sentences(text, biased_words):
    sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s', text)
    biased_sentences = []
    for sentence in sentences:
        for word in biased_words:
            if is_word_present(sentence, word):
                biased_sentences.append((word, sentence))
                break
    return biased_sentences


def print_biased_sentences(biased_sentences):
    if biased_sentences:
        print("Biased sentences:")
        for word, sentence in biased_sentences:
            highlighted_sentence = highlight_word_in_sentence(word, sentence)
            print(f"\033[91mBiased word: {word}\033[0m")
            print(highlighted_sentence)
            print()
    else:
        print("No biased sentences found.")


def highlight_word_in_sentence(word, sentence):
    highlighted_sentence = sentence.lower().replace(word.lower(), f"\033[91m{word.upper()}\033[0m")
    return highlighted_sentence


url = 'https://avinuty.ac.in'
text_content = fetch_text_from_url(url)
text_content = remove_non_alpha(text_content)

df = pd.read_excel('gender_biased_words.xlsx', sheet_name='word')
biased_words = df['word'].tolist()

biased_sentences = find_biased_sentences(text_content, biased_words)
print_biased_sentences(biased_sentences)
# Out:
# Biased sentences:
# Biased word: women
#
#
#
#
#
#
#
#
# avinashilingam university for WOMEN  coimbatore  tamil nadu  india
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   avinashilingam institute for home science and higher education for WOMEN
#
#
#   deemed to be university  estd us  of ugc act  category a by mhrd
#   reaccredited with a grade by naaccgpa  category i by ugc
# coimbatore  tamil nadu india
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# accessibility options
# screen reader
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# menu
#
#
#
#
#
#
#
# about us
#
# founder
# genesis
# about us
# vision and mission
# vision
#
# chair
#
#  padmabhushan drtsavinashilingam ayya
#
#  drprajammmal pdevadas
#  swami jagadatmananda saraswati
#  tsdhadapani chettiar
#
#
#
# core values
#
#
# strategic plan
#
#
#  perspective  deployment plan
#
#
# organogram
# know our institutionvideo
# institutional distinctiveness
# best practices
#
#
#
#
#
# authorities
#
# chancellor
#
# vice chancellor
# deans of schools
#
# statutory body  other committees
#
# general body
#  board of management
#
#  planning  monitoring
#  academic council
#
# boards of studies
#
#  finance committee
# building committee
# library committee
# other committees
#
#
#
#
#
#
#
# administration
#
# registrar
# registrars office
#
#  academic section
#  administration section
#
# controller of examinations
# public relation office
#  finance office
#  policiesmanuals
#  reservation roster
# liaisonnodal officer
# citizen charter
# staff directory
#
#  teaching
#  nonteaching
#
#
#
#
#
#
#
# academics
#
#  programmes offered
#
#
#
#  programme outcomes
#  hand book  calendar
#
# curriculum framework
#
#   outreach programmes
#
#
#
#
#
#
#
# research
#
#  research
#
#
# centralized facilities
#
#  advanced research lab
#
#  prof cnr rao research centre
# center for machine learning and intelligence
#  centre for artificial intelligence and robotics
#  cmet research centre
# innovation and incubation cente
# aiuaiaadc
# entrepreneurship development cell
# institutions innovation council
#
#
#  facilities to support research
#
#
#
#
#
# examination
#
#
# manual and evaluation
# it integration
#
# calendar of events
#
#
# 								        odd semester calendar of events for all programmes except first year
#
# 								       odd semester calendar of events for all first year programmes
#
# 								        revised even semester calendar of events for all programmes
#
#
#
#
# results
#
# time table
# revaluation retotalling  transparency
#
#
# certificates
#
# duplicate certificate
# transcript certificate
# genuniness certificate
#
#
#  comprehensive question paper templates
#  evaluation  assessment rubrics
# phd tracking system
# ugcnad digilocker
#
#
#
#
#
#
# schools
#
#  school of home science
#  school of physical sciences  computational sciences
#  school of biosciences
#  school of arts  social sciences
# school of  commerce  management
# school of allied and healthcare sciences
#  school of education
#
#  school of engineering
#
#
#
#
#
# facilities
#
# library
#
# computer centre
#
#
#
# eresources
#
# library eresources
# internal platform
#
# ecampus lms
# google class room
#
#
#  external platform
#
# swayam mooc
# epgpathsala
# nmeict
#
#
#
#
#
#
#
# centres
#
#  academic  service centres
#
# centre for international education
# WOMENs studies centre
#
#  gandhian studies centre
#   drambedkar studies centre
# life long learing centre
#
#
#  centralized facilities
#
#  advanced research lab
#
#  prof cnr rao research centre
# center for machine learning and intelligence
#  centre for artificial intelligence and robotics
#  cmet research centre
# innovation and incubation cente
# aiuaiaadc
# entrepreneurship development cell
# institutions innovation council
#
#
#
# skill training centre
#
#
#
#
#
# infrastructure
#
#
#  teaching  learning
# laboratory
# other facilities
# divyangjan facilities
#
# facilities for differently abled
#
# divyangjan friendliness resources
#
#  ramp rail and lift facility
#  disabled friendly washroom
#  signage
#  assistive technology and facilities
#
#
#
#
# hostel
# care
#
# media centre
#
# other facilities
#
# hostel
# auditorium
# canteen
# health centre
# saradalaya press
#
#
#
#  imf
#
# green initiatives
#
#
# energy conservation
#
# solar energy
# biogas plant
# sensor based energy conservation
# use of led lights
#
#
#
# management of waste
#
# solid waste management
# liquid waste management
# biomedical waste management
# e waste management
# waste recycling system
#
#
#
# water conservation measures
#
# rain water harvesting
# borewell open well recharge
# construction of tanks  bunds
# waste water recycling
#
#
#
# green campus initiatives
#
# restricted entry of automobiles
# use of bicyclesbattery powered vehicle
# pedestrian friendly pathways
# ban on use of plastic
# landscaping with trees and plants
#
#
#
#
#
# ict facilities
#
#
# ict video
# ict facilities  short video
#
#
# sports
# facilities for staff
#
#
#
#
#
#  admissions
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# admission  online applications open for ug pg bedbpedmed diploma  phd courses
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# announcements
#
#
#
#
#
#  view all
#
#
#
#
#
#
#
#
#             sealed tenders are invited for the  design and development of our institution website last date to apply
#
#
#             sealed tenders are invited for  civil maintenance work in school of engineering campus last date to apply
#
#
#            circular for vacation details
#
# parents meeting of the  newly admitted for ug courses
#
# campus i
#
# campus ii
#
#
#              cia ii time table for phd degree programme part i  part time  batch  may
#
#
#
#  cia  ii time table for all programmes ug pg bvoc  pg diploma  april
#
#
#
#
#
#
#  comprehensive examination   may  regular  arrear  examination time table for all programmes
#
#
#
#
#
#              remittance of even semester fee for academic year
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# quick links
#
# staff corner
#
#    student corner
#   recruitments
#   external links
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    academic bank of credits
#
#
# 	   national academic depository
#
#     	 ugc eresources
#
#     	   epgpathsala
#   spoken tutorial
# dsource
#
# eyantra
#
# vidyamitra
#
#
#
#
#  swayam mooc courses offered
#
#
#
#
#
#
#
#
#
#
#
#
# circularsguidelines
#
#
#
#
#
#
#
#
#
# announcements
#
#
#
#    scholarship
#
#
#
#     facilitation centre  scholarship help desk scst
#
#
#
# rules  regulations
#
#
#    swayam mooc courses offered
#
#
#
#
#
#     recruitment
#
#
#
#
#
#
#
#
#
#
#
#
#    rti act
#
#
#
#      anti ragging cell
#
#
#
#     equal opportunity cell
#
#
#    scst  obc complaints
#
#
#
#
#      grievance redressal cell
#
#
#
#
#
#  internal complaints committee sh
#
#
#
#       student capability enhancement
#
#      student council
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                             self development and empowerment of WOMEN through modern scientific and value based education to enable them to lead
#                         a purposeful life filled with moral and spiritual values
#
# the mission of the  university is to provide quality education of global standards on a strong foundation of indian values and traditions to WOMEN students
# based on current advances in science technology and societal demands with emphasis on commitment to social progress peace harmony and national integration
#
#
#
#
#
#
#
#
#  academic  excellence
# our institution strives to meet  the highest standard of excellence in virtual and ict enabled teaching learning methodology research continuous  inhouse and outbound faculty  improvement programmes    ensures continuous engagement in the scholarly activities in the pursuit of leveraging  innovation creativity and excellence brings up to date  changes  in academic activity to  implement systems and navigate   the  functions to inorder to meet the sustainable education standards and practices our research activities and outcomes   continue to have global significance  and meaningful impact
#
# social relevance and WOMEN empowerment
#
# 							promotes national integration among the students  through implementing the policies by means of ncc nss css yoga sports and  encourage students to be participative in all intra and inter competitions and social awareness programmes imparts skill based education and learning in empowering WOMEN to venture into start up businesses encourage WOMEN to hold leadership roles and facilitate   in sourcing   their dream  career by extending relevant training and industry awareness programmes
#
#  accountability and transparency
#
# 							issues in internal governance of the institution in terms of the processes connected with admissions registration examinations evaluations payment of fees and a host of other functions are addressed with   close attention in ensuring quality and transparency  it  promotes continuous improvement and take responsibility for professional growth and development of the students staff and institute by egovernance and  digitalization where its use make  all the stake holders of the institute to work at ease
#
# diversity  inclusion
#
# upholds the highest ethical values integrity and   professionalism by fostering   inclusive environment  where everyone can develop their full potential and contribute to the interest of the society as a whole and perform well in their careers ensures non discrimination and promotes inclusion in all levels of education
#
# vitality of culture and values
#
# our institution embraces cultural values across the institution and treat people with dignity  and encourage feelings of importance in all all festivals  and its values are celebrated with all its pomp and glory traditional values and prayers are followed  gandhian  principles and dr ambedkars thoughts are shared and adopted
#
#
#
#
#
#
#
#
#
#
#
#
#
#  upcoming events
# 							 view all
#
#
#
#
#
#
#
#
# five days summer camp  you too can sing from  to
#
#
#
# days summer camp  spoken hindi course  to
#
#
#
#
#  international conference on innovative applications of artificial intelligence iaai   th  th sep
#
#
#
#    phd vivavoce exam notification
#
#
#
#
#
#
#
#
#
#  photo galleryevents
#                         	  view all
#
#
#
#
#
#
#     pudhumai penn scheme  appreciation ceremony
#
#
#
#      lighting  ceremony in honour of outgoing students
#
#
#
#
#      natcon
#
#
#
#
#      techwings k
#
#
#
#
#      avega
#
#
#
#      int conference on revamping food and nutrition for the next generation  addressing personal public and planetary sustainable health mar
#
#
#
#
#
#
#
#
#
#
# th convocation
#
#
# campus tour
#
# campus tour
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# links
#
#
#   vidwan
#   shodhganga
#    national cyber crime reporting portal
#    national council for teacher education
#    iqac
#    naac
#    nirf
#
#
#
#
#
# digital action plan
#
#   academic bank of credits
#   national academic depository
#  ugc eresources
#   epgpathshala
#   swayam
#   swayam prabha
#   ugcmoocs
#
#
#
#
#
# keep in touch
#
#
#
#
#
#
#
#
#
#  mandatory diclosure
#
#
#
#
#
#
#
#
#
#
#
#
# visitors count
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# logo new new   new new new new new new new new new           new   new new new new

# %%
from flask import Flask, render_template, request
import requests
from bs4 import BeautifulSoup
from io import BytesIO
from PIL import Image
import pytesseract
import pandas as pd
import re

app = Flask(__name__)

def extract_image_links(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    img_tags = soup.find_all("img")
    img_links = []
    for img in img_tags:
        img_link = img.get("src")
        if img_link.endswith(".jpg") or img_link.endswith(".jpeg") or img_link.endswith(".png"):
            img_links.append(img_link)
    return img_links, soup

def extract_text_from_image(image):
    try:
        image = Image.open(BytesIO(image))
        text = pytesseract.image_to_string(image)
        return text.strip()  # Remove leading/trailing white spaces from the extracted text
    except pytesseract.TesseractNotFoundError:
        print("Tesseract is not installed or not found in the system's PATH.")
        return None
    except Exception as e:
        print(f"Error in image processing: {e}")
        return None

def fetch_text_from_url(url):
    img_links, soup = extract_image_links(url)
    text_content = soup.get_text()
    image_alt_text = []
    for img in soup.find_all('img'):
        if 'alt' in img.attrs:
            image_alt_text.append(img.attrs['alt'])
    text_content += ' '.join(image_alt_text)
    return text_content

def remove_non_alpha(text):
    return re.sub(r'[^a-zA-Z\s]', '', text)

def is_word_present(sentence, word):
    words = sentence.split()
    for w in words:
        clean_word = ''.join(c for c in w if c.isalnum())
        if clean_word.lower() == word.lower():
            return True
    return False

def find_biased_sentences(text, biased_words):
    sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s', text)
    biased_sentences = []
    for sentence in sentences:
        for word in biased_words:
            if is_word_present(sentence, word):
                biased_sentences.append((word, sentence))
                break
    return biased_sentences

@app.route('/')
def index():
    return render_template('index.html')

@app.route('/result', methods=['POST'])
def result():
    url = request.form['url']
    text_content = fetch_text_from_url(url)
    text_content = remove_non_alpha(text_content)
    df = pd.read_excel('gender_biased_words.xlsx', sheet_name='word')
    biased_words = df['word'].tolist()
    biased_sentences = find_biased_sentences(text_content, biased_words)
    return render_template('result.html', biased_sentences=biased_sentences)

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [16/May/2023 14:23:23] "GET / HTTP/1.1" 200 -
# [2023-05-16 14:23:38,927] ERROR in app: Exception on /result [POST]
# Traceback (most recent call last):
#   File "C:\Users\Hi\Anaconda3\envs\venv\lib\site-packages\flask\app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Hi\Anaconda3\envs\venv\lib\site-packages\flask\app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Hi\Anaconda3\envs\venv\lib\site-packages\flask\app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Hi\Anaconda3\envs\venv\lib\site-packages\flask\app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\Hi\AppData\Local\Temp\ipykernel_19264\3917875061.py", line 78, in result
#     return render_template('result.html', biased_sentences=biased_sentences)
#   File "C:\Users\Hi\Anaconda3\envs\venv\lib\site-packages\flask\templating.py", line 146, in render_template
#     template = app.jinja_env.get_or_select_template(template_name_or_list)
#   File "C:\Users\Hi\Anaconda3\envs\venv\lib\site-packages\jinja2\environment.py", line 1081, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "C:\Users\Hi\Anaconda3\envs\venv\lib\site-packages\jinja2\environment.py", line 1010, in get_template
#     return self._load_template(name, globals)
#   File "C:\Users\Hi\Anaconda3\envs\venv\lib\site-packages\jinja2\environment.py", line 969, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "C:\Users\Hi\Anaconda3\envs\venv\lib\site-packages\jinja2\loaders.py", line 126, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "C:\Users\Hi\Anaconda3\envs\venv\lib\site-packages\flask\templating.py", line 62, in get_source
#     return self._get_source_fast(environment, template)
#   File "C:\Users\Hi\Anaconda3\envs\venv\lib\site-packages\flask\templating.py", line 98, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: result.html
# 127.0.0.1 - - [16/May/2023 14:23:38] "POST /result HTTP/1.1" 500 -
# [2023-05-16 14:23:54,146] ERROR in app: Exception on /result [POST]
# Traceback (most recent call last):
#   File "C:\Users\Hi\Anaconda3\envs\venv\lib\site-packages\flask\app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Hi\Anaconda3\envs\venv\lib\site-packages\flask\app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Hi\Anaconda3\envs\venv\lib\site-packages\flask\app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Hi\Anaconda3\envs\venv\lib\site-packages\flask\app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\Hi\AppData\Local\Temp\ipykernel_19264\3917875061.py", line 78, in result
#     return render_template('result.html', biased_sentences=biased_sentences)
#   File "C:\Users\Hi\Anaconda3\envs\venv\lib\site-packages\flask\templating.py", line 146, in render_template
#     template = app.jinja_env.get_or_select_template(template_name_or_list)
#   File "C:\Users\Hi\Anaconda3\envs\venv\lib\site-packages\jinja2\environment.py", line 1081, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "C:\Users\Hi\Anaconda3\envs\venv\lib\site-packages\jinja2\environment.py", line 1010, in get_template
#     return self._load_template(name, globals)
#   File "C:\Users\Hi\Anaconda3\envs\venv\lib\site-packages\jinja2\environment.py", line 969, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "C:\Users\Hi\Anaconda3\envs\venv\lib\site-packages\jinja2\loaders.py", line 126, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "C:\Users\Hi\Anaconda3\envs\venv\lib\site-packages\flask\templating.py", line 62, in get_source
#     return self._get_source_fast(environment, template)
#   File "C:\Users\Hi\Anaconda3\envs\venv\lib\site-packages\flask\templating.py", line 98, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: result.html
# 127.0.0.1 - - [16/May/2023 14:23:54] "POST /result HTTP/1.1" 500 -
